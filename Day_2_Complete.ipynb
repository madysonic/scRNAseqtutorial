# %% [markdown]
# <a href="https://colab.research.google.com/github/madysonic/scRNAseqtutorial/blob/main/Day_2_Complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Day 2. Statistics in Single Cell RNA seq data**

# %% [markdown]
# We will use R for the remainder of this course, to set your google co lab to R language, change runtime type from Python to R.
#
# We can't mount google drive to co-lab in R runtimes, so upload the X.csv, obs.csv and var.csv to the session storage.
#
# (File icon on the left, then document with arrow on it)![Screenshot 2024-11-13 at 10.53.48.png](data:image/png;base64,...)
#
# Be aware that if the runtime expires, you will have to reupload these files.
# You can avoid your runtime expiring by keeping the co-lab notebook as a separate webpage.

# %% [markdown]
# **1. Install and load the required packages**

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("limma")
install.packages('ggrepel')
install.packages("WebGestaltR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.2 (2025-10-31)
#
# Installing package(s) 'BiocVersion', 'limma'
#
# also installing the dependency ‘statmod’
#
#
# Old packages: 'data.table', 'gert', 'knitr', 'later', 'lifecycle', 'selectr',
#   'tidyr', 'xfun'
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘rngtools’, ‘iterators’, ‘doRNG’, ‘doParallel’, ‘foreach’, ‘svglite’, ‘igraph’, ‘apcluster’

# %%
library(dplyr)
library(ggplot2)
library(tidyr)
library(limma)
library(ggrepel)
library(WebGestaltR)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ******************************************
#
#
# *                                        *
#
#
# *          Welcome to WebGestaltR !      *
#
#
# *                                        *
#
#
# ******************************************

# %% [markdown]
# **1. Read in the 3 csv files**
# * X is the expression matrix
# * obs is the observations/metadata
# * var is the gene names

# %%
exp_data <- read.csv('/content/X.csv', header=FALSE) # normalised expression matrix, cells and genes
metadata <-read.csv('/content/obs.csv')
var_data<- read.csv('/content/var.csv')

head(exp_data)
head(metadata)
head(var_data)
# Out:
#   V1          V2        V3         V4          V5         V6         V7
# 1 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965 -0.1256334
# 2 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965 -0.1256334
# 3 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965 -0.1256334
# 4 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965 -0.1256334
# 5 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965 -0.1256334
# 6 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965 -0.1256334
#   V8         V9         V10         ⋯ V5842      V5843      V5844
# 1 -0.2100703 -0.1098231 -0.08605047 ⋯  8.4439458 -0.2299743 -0.1876729
# 2 -0.2100703 -0.1098231 -0.08605047 ⋯ -0.2414715 -0.2299743 -0.1876729
# 3 -0.2100703 -0.1098231 -0.08605047 ⋯ -0.2414715 -0.2299743 -0.1876729
# 4 -0.2100703 -0.1098231 -0.08605047 ⋯ -0.2414715 -0.2299743 -0.1876729
# 5 -0.2100703 -0.1098231 -0.08605047 ⋯ -0.2414715 -0.2299743 -0.1876729
# 6 -0.2100703 -0.1098231 -0.08605047 ⋯ -0.2414715 -0.2299743 -0.1876729
#   V5845      V5846      V5847       V5848      V5849      V5850
# 1 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671 -0.06982737
# 2 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671 -0.06982737
# 3 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671 -0.06982737
# 4 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671 -0.06982737
# 5 -0.2382954 -0.1083122 -0.06937566  5.3992868 -0.1775671 -0.06982737
# 6 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671 -0.06982737
#   V5851
# 1 -0.3230621
# 2 -0.3230621
# 3 -0.3230621
# 4 -0.3230621
# 5 -0.3230621
# 6 -0.3230621
#   CellID    Patient Author  Tissue                      Disease_stage Age
# 1 sc_b1_A08 33572   Hu_2020 Benign fallopian tube cells Benign        64
# 2 sc_b1_B06 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 3 sc_b1_B08 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 4 sc_b1_B11 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 5 sc_b1_C15 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 6 sc_b1_C18 33572   Hu_2020 Benign fallopian tube cells Benign        64
#   n_genes n_genes_by_counts total_counts pct_counts_in_top_50_genes
# 1 1326    1326              142098       24.09182
# 2 1599    1599              273240       25.74294
# 3 2298    2298              193108       24.94614
# 4 2100    2100              195696       20.84202
# 5 1793    1793              279434       19.77569
# 6 1335    1335              328526       27.70253
#   pct_counts_in_top_100_genes pct_counts_in_top_200_genes
# 1 36.65006                    55.25201
# 2 34.62194                    47.67201
# 3 32.24620                    42.47468
# 4 29.20755                    41.62834
# 5 27.73965                    39.91712
# 6 36.29728                    49.93090
#   pct_counts_in_top_500_genes leiden Celltype
# 1 86.71480                    0      Secretory Epithelial-1
# 2 74.23291                    0      Secretory Epithelial-1
# 3 62.87777                    1      Secretory Epithelial-2
# 4 66.75303                    0      Secretory Epithelial-1
# 5 66.52304                    1      Secretory Epithelial-2
# 6 78.92983                    0      Secretory Epithelial-1
#   Gene     n_cells n_cells_by_counts mean_counts pct_dropout_by_counts
# 1 PLEKHN1  127     127                1.582620   97.21308
# 2 C1orf159 383     383               11.393461   91.59535
# 3 B3GALT6  287     287                4.430546   93.70200
# 4 FAM132A   39      39                1.260478   99.14417
# 5 SCNN1D   329     329                7.168751   92.78034
# 6 PUSL1    425     425               13.996269   90.67369
#   total_counts highly_variable means      dispersions dispersions_norm
# 1  7212        True            0.01804155 1.833444    0.7781531
# 2 51920        True            0.15081387 1.673782    0.6673490
# 3 20190        True            0.06731816 1.507138    0.5517003
# 4  5744        True            0.01762634 1.701863    0.6868375
# 5 32668        True            0.10859225 1.673323    0.6670306
# 6 63781        True            0.15783719 2.050473    0.9287682
#   mean        std
# 1 0.009044333 0.09574012
# 2 0.065633356 0.30348997
# 3 0.032744878 0.19488919
# 4 0.007682837 0.10071693
# 5 0.047073752 0.25428997
# 6 0.070341273 0.30717181

# %% [markdown]
# **2. Make the row names of exp_data be CellIDs, and the column names be gene names**

# %%
rownames(exp_data)<-metadata$CellID
colnames(exp_data)<-var_data$Gene

head(exp_data)
# Out:
#           PLEKHN1     C1orf159  B3GALT6    FAM132A     SCNN1D     PUSL1
# sc_b1_A08 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965
# sc_b1_B06 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965
# sc_b1_B08 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965
# sc_b1_B11 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965
# sc_b1_C15 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965
# sc_b1_C18 -0.09446754 -0.216262 -0.1680179 -0.07628149 -0.1851184 -0.2289965
#           MXRA8      LOC148413  CDK11B     LOC100129534 ⋯ DNASE1L1   TAZ
# sc_b1_A08 -0.1256334 -0.2100703 -0.1098231 -0.08605047  ⋯  8.4439458 -0.2299743
# sc_b1_B06 -0.1256334 -0.2100703 -0.1098231 -0.08605047  ⋯ -0.2414715 -0.2299743
# sc_b1_B08 -0.1256334 -0.2100703 -0.1098231 -0.08605047  ⋯ -0.2414715 -0.2299743
# sc_b1_B11 -0.1256334 -0.2100703 -0.1098231 -0.08605047  ⋯ -0.2414715 -0.2299743
# sc_b1_C15 -0.1256334 -0.2100703 -0.1098231 -0.08605047  ⋯ -0.2414715 -0.2299743
# sc_b1_C18 -0.1256334 -0.2100703 -0.1098231 -0.08605047  ⋯ -0.2414715 -0.2299743
#           PLXNA3     UBL4A      SLC10A3    GAB3        MPP1       F8
# sc_b1_A08 -0.1876729 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671
# sc_b1_B06 -0.1876729 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671
# sc_b1_B08 -0.1876729 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671
# sc_b1_B11 -0.1876729 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671
# sc_b1_C15 -0.1876729 -0.2382954 -0.1083122 -0.06937566  5.3992868 -0.1775671
# sc_b1_C18 -0.1876729 -0.2382954 -0.2910066 -0.06937566 -0.3154077 -0.1775671
#           RAB39B      TMLHE
# sc_b1_A08 -0.06982737 -0.3230621
# sc_b1_B06 -0.06982737 -0.3230621
# sc_b1_B08 -0.06982737 -0.3230621
# sc_b1_B11 -0.06982737 -0.3230621
# sc_b1_C15 -0.06982737 -0.3230621
# sc_b1_C18 -0.06982737 -0.3230621

# %% [markdown]
# ##**Initial visualisations of the data**
# **1. Calculate the total number of cells per patient**

# %%
cells_per_patient <- metadata %>%
  group_by(Patient) %>%
  tally()
names(cells_per_patient) <- c('Patient','Total_Cells')
cells_per_patient # low cell counts can be due to low yield, poor results on QC, etc
# Out:
#    Patient Total_Cells
# 1  11543   221
# 2  11545   503
# 3  11553   650
# 4  15066   481
# 5  15072   525
# 6  33572   481
# 7  33778   175
# 8  34350   238
# 9  34659   918
# 10 35773    38

# %%
head(cells_per_patient)
# Out:
#   Patient Total_Cells
# 1 11543   221
# 2 11545   503
# 3 11553   650
# 4 15066   481
# 5 15072   525
# 6 33572   481

# %% [markdown]
# **2. Use ggplot to plot this as a bar graph**

# %%
ggplot(cells_per_patient, aes(x = reorder(Patient, -Total_Cells), y = Total_Cells)) +
  geom_bar(stat = "identity", fill = "skyblue") +
  labs(title = "Total Number of Cells per Patient", x = "Patient ID", y = "Total Number of Cells") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# **3. Calculate and plot total cell counts per disease stage**

# %%
cells_per_stage <- metadata %>%
  group_by(Disease_stage) %>%
  tally()
names(cells_per_stage) <- c('Disease_stage','Total_Cells')

# %%
ggplot(cells_per_stage, aes(x = Disease_stage, y = Total_Cells, fill = Disease_stage)) +
  geom_bar(stat = "identity") +
  labs(title = "Total Number of Cells per Disease Stage", x = "Disease Stage", y = "Total Number of Cells") +
  theme_minimal() +
  scale_fill_brewer(palette = "Dark2")
# Out:
# plot without title

# %%
ggplot(cells_per_patient, aes(x = reorder(Patient, -Total_Cells), y = Total_Cells)) +
  geom_bar(stat = "identity", fill = "skyblue") +
  labs(title = "Total Number of Cells per Patient", x = "Patient ID", y = "Total Number of Cells") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# **4. Calculate and plot counts of cell types per disease stage**

# %%
cell_counts <- metadata %>%
  group_by(Celltype, Disease_stage) %>%
  tally()

# %%
ggplot(cell_counts, aes(x = Disease_stage, y = n, fill = Celltype)) +
  geom_bar(stat = "identity", position = "dodge") +
  labs(title = "Cell Type Distribution by Disease Stage", x = "Disease Stage", y = "Cell Count") +
  theme_minimal()  +
  scale_fill_brewer(palette = "Dark2")
# Out:
# plot without title

# %%
cell_counts_patient <- metadata %>%
  group_by(Patient, Celltype) %>%
  tally(name = "n")

ggplot(cell_counts_patient, aes(x = factor(Patient), y = n, fill = Celltype)) +
  geom_bar(stat = "identity", position = "dodge") +
  labs(title = "Cell Type Distribution per Patient",
       x = "Patient", y = "Cell Count") +
  theme_minimal() +
  scale_fill_brewer(palette = "Dark2") +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# ## **Differential gene expression**
# * Perform a differential gene expression test between between Secretory Epithelial-1 and Secretory Epithelial-2 using the limma package

# %% [markdown]
# **1. Subset the metadata and expression data to the two secretory epithelial cell types**

# %%
secretorymeta<- subset(metadata, metadata$Celltype %in%c('Secretory Epithelial-1','Secretory Epithelial-2'))
secretoryexp<- subset(exp_data, rownames(exp_data) %in% secretorymeta$CellID)

# %% [markdown]
# **2.Check dimensions of secretory cell metadata and expression match, do they have the same number of cells?**

# %%
dim(secretorymeta)
dim(secretoryexp)
# Out:
# [1] 2742   15
# [1] 2742 5851

# %% [markdown]
# **3. Transpose the expression matrix, so columns = cells and rows = genes
# (this is the input format required by limma)**
# * Check cell IDs match

# %%
secretoryexp <- t(secretoryexp)
identical(colnames(secretoryexp), secretorymeta$CellID)
# Out:
# [1] TRUE

# %% [markdown]
# **4. Perform differential gene expression test**

# %%
design <- model.matrix(~ Celltype, data = secretorymeta)
fit <- lmFit(secretoryexp, design) # limma uses FDR by default
fit <- eBayes(fit, trend = TRUE)

# %% [markdown]
# **5. Print top 20 differentially expressed gene**

# %%
top20genes <- topTable(fit, coef = 2, number = 25) # coef = 2 → celltype effect (difference between groups), top 20 results
print(top20genes)
# Out:
#              logFC      AveExpr         t       P.Value     adj.P.Val        B
# DNAJB1   1.4062627  0.142315431  49.00135  0.000000e+00  0.000000e+00 853.1227
# MAFF     1.3778254  0.168383814  44.62554  0.000000e+00  0.000000e+00 739.5503
# SERTAD1  1.3430332  0.124781415  42.82456 2.739357e-307 5.342660e-304 693.2463
# SOD2     1.1602063  0.017821231  37.74321 1.913977e-251 2.799671e-248 564.9803
# RND3     1.2265344  0.082249456  37.52431 4.395981e-249 5.144176e-246 559.5570
# ZC3H12A  1.2198683  0.102495529  37.40139 9.265636e-248 9.035539e-245 556.5164
# CLDN10  -1.2270969  0.128654101 -36.93004 1.072158e-242 8.961710e-240 544.8863
# NR4A1    1.0871123  0.222794414  33.88127 1.655037e-210 1.210453e-207 470.9532
# SLC40A1 -1.1332151  0.130464704 -33.39883 1.631700e-205 1.060787e-202 459.4833
# ATF3     1.1110467  0.214488462  33.37096 3.164240e-205 1.851397e-202 458.8227
# CYR61    1.1093335  0.162107924  33.21465 1.292031e-203 6.872428e-201 455.1225
# NCOA7    1.1026419  0.215414113  32.39760 3.012891e-195 1.469035e-192 435.9036
# HBEGF    1.1038626  0.066437061  31.69671 3.828290e-188 1.723025e-185 419.5875
# PLK2     1.0814605  0.077957629  31.62777 1.896257e-187 7.925000e-185 417.9916
# S100A10  0.8335237 -0.129505701  29.67079 4.993443e-168 1.947775e-165 373.3897
# CPM     -1.0407409 -0.020152442 -29.53571 1.037545e-166 3.794173e-164 370.3638
# PKHD1L1 -1.1425677  0.184232910 -28.83068 6.952654e-160 2.392940e-157 354.6876
# HSPB8    0.9641139 -0.001729349  28.57837 1.835708e-157 5.967072e-155 349.1264
# CXCL2    1.0002045  0.176583789  28.38444 1.310242e-155 4.034856e-153 344.8699
# FOSB     0.8962621  0.180870654  26.44673 1.763637e-137 5.159520e-135 303.2411
# NXF1     0.9692117  0.102745071  26.32293 2.396077e-136 6.675928e-134 300.6394
# PLAUR    0.9036905 -0.031556929  26.02105 1.346005e-133 3.579761e-131 294.3264
# LDLR     0.9282173  0.023012612  25.94736 6.271105e-133 1.595315e-130 292.7919
# UAP1     0.9143387  0.045437172  25.06823 4.792037e-125 1.168259e-122 274.6930
# CD83     0.9229742  0.126121181  24.74723 3.287755e-122 7.694662e-120 268.1813

# %% [markdown]
# **6. Plot a volcano plot of top 100 differentially expressed genes**

# %%
top_genes_df <- topTable(fit, coef = 2, number = 100)
top_genes_df$significance <- ifelse(top_genes_df$P.Value < 0.05 & abs(top_genes_df$logFC) > 1,
                                    "Significant", "Not Significant")

# %%
volcanoplot <- ggplot(top_genes_df, aes(x = logFC, y = -log10(P.Value), color = significance)) +
  # geom_point(alpha = 0.6, size = 2) +
  scale_color_manual(values = c("Not Significant" = "gray", "Significant" = "blue")) +
  theme_minimal() +
  geom_vline(xintercept = c(-1, 1), linetype = "dashed", color = "black") +
  geom_hline(yintercept = -log10(0.05), linetype = "dashed", color = "black") +
  geom_jitter(
    width = 0.05,   # small horizontal jitter
    height = 0,     # no vertical jitter
    alpha = 0.6,
    size = 2
  ) +
  labs(
    title = "Top 100 differentially expressed genes between secretory cell types 1 and 2",
    x = expression(log[2]~"fold change"),
    y = expression(-log[10]~"(p-value)")
  ) +
  theme(legend.title = element_blank()) +
  theme(legend.position = "top")

volcanoplot
# Out:
# plot without title

# %% [markdown]
# **7. Add gene names to the singificantly differentially expressed genes**

# %%
volcanoplotlabelled <- volcanoplot +
  geom_text_repel(aes(label = ifelse(significance == "Significant", rownames(top_genes_df), "")),
                                                       box.padding = 0.5, point.padding = 0.5,
                                                       max.overlaps = 10, size = 2.8)
volcanoplotlabelled
# Out:
# plot without title

# %% [markdown]
# ##**Gene Set Enrichment Analysis**
# * We can get more information about what biological processes or pathways each cell type might be enriched for using gene set enrichment analysis
# * This will use a package WebGestaltR

# %% [markdown]
# **1. Import the list of ranked genes from cell types we generated using Scanpy yesterday**

# %%
rankedgenes <- read.csv("/content/celltypemarkergenes.csv")
head(rankedgenes)
# Out:
#   Secretory.Epithelial.1_n Secretory.Epithelial.1_s Secretory.Epithelial.2_n
# 1 CLDN10                   30.74710                 DNAJB1
# 2 SLC40A1                  30.24609                 MAFF
# 3 SPARCL1                  24.47402                 ATF3
# 4 PKHD1L1                  23.84137                 NR4A1
# 5 SORL1                    23.07276                 NCOA7
# 6 SCGB1D2                  16.61122                 SERTAD1
#   Secretory.Epithelial.2_s STIC.lesion_n STIC.lesion_s Ciliated.Epithelial_n
# 1 37.68798                 HLA-DRB1      25.37824      FAM183A
# 2 36.72523                 HLA-DQA1      25.25888      C1orf194
# 3 34.06892                 HLA-DPB1      24.67608      C20orf85
# 4 33.73787                 HLA-DPA1      23.77374      CAPS
# 5 33.50495                 HLA-DQB1      22.30958      TPPP3
# 6 33.20293                 HSPB8         21.70216      PIFO
#   Ciliated.Epithelial_s Fibroblast_n Fibroblast_s Immune_n Immune_s
# 1 40.50676              TIMP3        16.25925     SRGN     18.64777
# 2 40.50064              UBB          13.45883     LAPTM5   17.20337
# 3 40.39793              SPARC        11.99632     RGS1     16.80215
# 4 40.35849              IGFBP5       11.62716     PTPRC    16.33096
# 5 40.34295              LGALS1       11.52522     ARHGDIB  16.24919
# 6 40.26876              DCN          11.15032     CD53     15.88344
#   High.Grade.Carcinoma_n High.Grade.Carcinoma_s
# 1 HMGA1                  27.12001
# 2 S100A10                26.48133
# 3 S100A6                 25.13075
# 4 KRT7                   24.91474
# 5 S100A16                24.25871
# 6 SH3BGRL3               23.24509

# %% [markdown]
# **2. We will look at Secretory Epithelial-1, Secretory Epithelial-2 and STIC lesion cell clusters**
# * Create  subsets of gene files for each cell type

# %%
SE1 <- rankedgenes[, colnames(rankedgenes) %in% c('Secretory.Epithelial.1_n', 'Secretory.Epithelial.1_s'), drop = FALSE]
SE2 <- rankedgenes[, colnames(rankedgenes) %in% c('Secretory.Epithelial.2_n', 'Secretory.Epithelial.2_s'), drop = FALSE]
STIC <- rankedgenes[, colnames(rankedgenes) %in% c('STIC.lesion_n', 'STIC.lesion_s'), drop = FALSE]

# %%
SE1
# Out:
#      Secretory.Epithelial.1_n Secretory.Epithelial.1_s
# 1    CLDN10                   30.74710
# 2    SLC40A1                  30.24609
# 3    SPARCL1                  24.47402
# 4    PKHD1L1                  23.84137
# 5    SORL1                    23.07276
# 6    SCGB1D2                  16.61122
# 7    TNFSF10                  16.12057
# 8    VTCN1                    16.10174
# 9    CPM                      16.04581
# 10   ID4                      15.56350
# 11   KIAA1324                 15.50540
# 12   ERP27                    15.30828
# 13   SLPI                     15.23990
# 14   WT1                      14.26887
# 15   RNASE1                   14.19947
# 16   THSD4                    12.82589
# 17   CRISP2                   12.71235
# 18   WDR77                    12.51570
# 19   PIK3IP1                  12.40148
# 20   SERPINA5                 12.35300
# 21   SPON1                    12.13148
# 22   ALCAM                    12.05494
# 23   NDP                      11.73345
# 24   AMFR                     11.54859
# 25   SERPINA3                 10.89332
# 26   KCNJ2                    10.65129
# 27   ADAM28                   10.64574
# 28   SLC34A2                  10.44017
# 29   BMPR1B                   10.25490
# 30   KIAA1551                 10.07297
# ⋮    ⋮                        ⋮
# 5822 CXCL2                    -17.69663
# 5823 NCOA7                    -17.82191
# 5824 ATF3                     -17.85610
# 5825 IL8                      -18.39103
# 5826 TNFAIP3                  -18.48248
# 5827 CTGF                     -18.77716
# 5828 ICAM1                    -18.78405
# 5829 ID2                      -18.89265
# 5830 FOSL1                    -18.89763
# 5831 GBP1                     -19.24625
# 5832 NXF1                     -19.35337
# 5833 LAMC2                    -19.51534
# 5834 HMGA1                    -19.54639
# 5835 CYR61                    -19.73204
# 5836 BIRC3                    -19.93552
# 5837 BAG3                     -19.97028
# 5838 UAP1                     -20.27483
# 5839 LDLR                     -21.32179
# 5840 HSPB8                    -22.16252
# 5841 PLAUR                    -22.44906
# 5842 HBEGF                    -22.45430
# 5843 PLK2                     -22.52063
# 5844 S100A6                   -22.85641
# 5845 ZC3H12A                  -24.19996
# 5846 S100A10                  -24.80158
# 5847 MAFF                     -25.78983
# 5848 SERTAD1                  -25.91429
# 5849 RND3                     -26.58433
# 5850 SOD2                     -26.76600
# 5851 DNAJB1                   -26.80540

# %% [markdown]
# **3. Save as rank files for input to webgestalt**

# %%
write.table(SE1, file = "/content/SE1rankedgenes.rnk", sep = "\t", row.names = FALSE, col.names = FALSE, quote = FALSE)
write.table(SE2, file = "/content/SE2rankedgenes.rnk", sep = "\t", row.names = FALSE, col.names = FALSE, quote = FALSE)
write.table(STIC, file = "/content/STICrankedgenes.rnk", sep = "\t", row.names = FALSE, col.names = FALSE, quote = FALSE)

# %%
SE1
# Out:
#      Secretory.Epithelial.1_n Secretory.Epithelial.1_s
# 1    CLDN10                   30.74710
# 2    SLC40A1                  30.24609
# 3    SPARCL1                  24.47402
# 4    PKHD1L1                  23.84137
# 5    SORL1                    23.07276
# 6    SCGB1D2                  16.61122
# 7    TNFSF10                  16.12057
# 8    VTCN1                    16.10174
# 9    CPM                      16.04581
# 10   ID4                      15.56350
# 11   KIAA1324                 15.50540
# 12   ERP27                    15.30828
# 13   SLPI                     15.23990
# 14   WT1                      14.26887
# 15   RNASE1                   14.19947
# 16   THSD4                    12.82589
# 17   CRISP2                   12.71235
# 18   WDR77                    12.51570
# 19   PIK3IP1                  12.40148
# 20   SERPINA5                 12.35300
# 21   SPON1                    12.13148
# 22   ALCAM                    12.05494
# 23   NDP                      11.73345
# 24   AMFR                     11.54859
# 25   SERPINA3                 10.89332
# 26   KCNJ2                    10.65129
# 27   ADAM28                   10.64574
# 28   SLC34A2                  10.44017
# 29   BMPR1B                   10.25490
# 30   KIAA1551                 10.07297
# ⋮    ⋮                        ⋮
# 5822 CXCL2                    -17.69663
# 5823 NCOA7                    -17.82191
# 5824 ATF3                     -17.85610
# 5825 IL8                      -18.39103
# 5826 TNFAIP3                  -18.48248
# 5827 CTGF                     -18.77716
# 5828 ICAM1                    -18.78405
# 5829 ID2                      -18.89265
# 5830 FOSL1                    -18.89763
# 5831 GBP1                     -19.24625
# 5832 NXF1                     -19.35337
# 5833 LAMC2                    -19.51534
# 5834 HMGA1                    -19.54639
# 5835 CYR61                    -19.73204
# 5836 BIRC3                    -19.93552
# 5837 BAG3                     -19.97028
# 5838 UAP1                     -20.27483
# 5839 LDLR                     -21.32179
# 5840 HSPB8                    -22.16252
# 5841 PLAUR                    -22.44906
# 5842 HBEGF                    -22.45430
# 5843 PLK2                     -22.52063
# 5844 S100A6                   -22.85641
# 5845 ZC3H12A                  -24.19996
# 5846 S100A10                  -24.80158
# 5847 MAFF                     -25.78983
# 5848 SERTAD1                  -25.91429
# 5849 RND3                     -26.58433
# 5850 SOD2                     -26.76600
# 5851 DNAJB1                   -26.80540

# %% [markdown]
# **4. Run Webgestalt GSEA for each rank file**

# %%
SE1Result <- WebGestaltR(
  enrichMethod = "GSEA", organism = "hsapiens",
  enrichDatabase = "pathway_KEGG", interestGeneFile = "/content/SE1rankedgenes.rnk",
  interestGeneType = "genesymbol", sigMethod = "top", topThr = 10, minNum = 5)

SE2Result <- WebGestaltR(
  enrichMethod = "GSEA", organism = "hsapiens",
  enrichDatabase = "pathway_KEGG", interestGeneFile = "/content/SE2rankedgenes.rnk",
  interestGeneType = "genesymbol", sigMethod = "top", topThr = 10, minNum = 5)

# STICResult <- WebGestaltR(
#   enrichMethod = "GSEA", organism = "hsapiens",
#   enrichDatabase = "pathway_KEGG", interestGeneFile = "/content/STICrankedgenes.rnk",
#   interestGeneType = "genesymbol", sigMethod = "top", topThr = 10, minNum = 5)
# Out:
# Loading the functional categories...
# Loading the ID list...
# Summarizing the uploaded ID list by GO Slim data...
# Performing the enrichment analysis...
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00020
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00040
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00062
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00072
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00130
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00220
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00290
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00400
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00430
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00471
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00524
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00533
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00601
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00650
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00670
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00750
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00780
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00785
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00900
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00920
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa01210
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa03010
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa03060
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa04122
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa04744
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa04950
# ”
# 1000 permutations of score complete...
# Begin affinity propagation...
# End affinity propagation...
# Begin weighted set cover...
# End weighted set cover...
# Generate the final report...
# Results can be found in the /content/Project_1767887522!
# Loading the functional categories...
# Loading the ID list...
# Summarizing the uploaded ID list by GO Slim data...
# Performing the enrichment analysis...
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00020
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00040
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00062
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00072
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00130
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00220
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00290
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00400
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00430
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00471
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00524
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00533
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00601
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00650
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00670
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00750
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00780
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00785
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00900
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa00920
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa01210
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa03010
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa03060
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa04122
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa04744
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for hsa04950
# ”
# 1000 permutations of score complete...
# Begin affinity propagation...
# End affinity propagation...
# Begin weighted set cover...
# End weighted set cover...
# Generate the final report...
# Results can be found in the /content/Project_1767887703!

# %% [markdown]
# Try different databases, use listGeneSet() to view the databases available

# %%
listGeneSet()
# Out:
#    name
# 1  geneontology_Biological_Process
# 2  geneontology_Biological_Process_noRedundant
# 3  geneontology_Cellular_Component
# 4  geneontology_Cellular_Component_noRedundant
# 5  geneontology_Molecular_Function
# 6  geneontology_Molecular_Function_noRedundant
# 7  pathway_KEGG
# 8  pathway_Panther
# 9  pathway_Reactome
# 10 pathway_Wikipathway
# 11 pathway_Wikipathway_cancer
# 12 network_CORUM
# 13 network_CORUMA
# 14 network_CPTAC_Proteomics_BRCA
# 15 network_CPTAC_Proteomics_COADREAD
# 16 network_CPTAC_Proteomics_HNSCC
# 17 network_CPTAC_Proteomics_LUAD
# 18 network_CPTAC_Proteomics_OV
# 19 network_CPTAC_Proteomics_UCEC
# 20 network_FunMap_DenseModules
# 21 network_FunMap_HierarchalModules
# 22 network_Kinase_phosphosite
# 23 network_Kinase_target
# 24 network_PPI_BIOGRID
# 25 network_PTMsigDB
# 26 network_TCGA_RNASeq_ACC
# 27 network_TCGA_RNASeq_BLCA
# 28 network_TCGA_RNASeq_BRCA
# 29 network_TCGA_RNASeq_CESC
# 30 network_TCGA_RNASeq_CHOL
# ⋮  ⋮
# 41 network_TCGA_RNASeq_LIHC
# 42 network_TCGA_RNASeq_LUAD
# 43 network_TCGA_RNASeq_LUSC
# 44 network_TCGA_RNASeq_MESO
# 45 network_TCGA_RNASeq_OV
# 46 network_TCGA_RNASeq_PAAD
# 47 network_TCGA_RNASeq_PCPG
# 48 network_TCGA_RNASeq_PRAD
# 49 network_TCGA_RNASeq_SARC
# 50 network_TCGA_RNASeq_SKCM
# 51 network_TCGA_RNASeq_STAD
# 52 network_TCGA_RNASeq_STES
# 53 network_TCGA_RNASeq_TGCT
# 54 network_TCGA_RNASeq_THCA
# 55 network_TCGA_RNASeq_THYM
# 56 network_TCGA_RNASeq_UCEC
# 57 network_TCGA_RNASeq_UCS
# 58 network_TCGA_RNASeq_UVM
# 59 network_Transcription_Factor_target
# 60 network_miRNA_target
# 61 disease_Disgenet
# 62 disease_GLAD4U
# 63 disease_OMIM
# 64 drug_DrugBank
# 65 drug_GLAD4U
# 66 phenotype_Human_Phenotype_Ontology
# 67 chromosomalLocation_CytogeneticBand
# 68 community-contributed_5htGeneSets_Conte
# 69 community-contributed_Hallmark50
# 70 community-contributed_MuscleGeneSets_Duddy_2017
#    description
# 1  The gene ontology biological process database was downloaded from http://www.geneontology.org/.
# 2  The gene ontology biological process database was downloaded from http://www.geneontology.org/. Then, we only contain the non-redundant categories by selecting the most general categories in each branch of the GO DAG structure from all categories with the number of annotated genes from 20 to 500.
# 3  The gene ontology cellular component database was downloaded from http://www.geneontology.org/.
# 4  The gene ontology cellular component database was downloaded from http://www.geneontology.org/. Then, we only contain the non-redundant categories by selecting the most general categories in each branch of the GO DAG structure from all categories with the number of annotated genes from 20 to 500.
# 5  The gene ontology molecular function database was downloaded from http://www.geneontology.org/.
# 6  The gene ontology molecular function database was downloaded from http://www.geneontology.org/. Then, we only contain the non-redundant categories by selecting the most general categories in each branch of the GO DAG structure from all categories with the number of annotated genes from 20 to 500.
# 7  The KEGG pathway database was downloaded from http://www.kegg.jp/.
# 8  The PANTHER pathway database was downloaded from http://www.pantherdb.org/pathway/.
# 9  The Reactome pathway database was downloaded from http://www.reactome.org/.
# 10 The Wikipathway database was downloaded from http://www.wikipathway.org/.
# 11 The Wikipathway database was downloaded from http://www.wikipathway.org/. This is the subset relevant to Clinical Proteomic Tumor Analysis Consortium.
# 12 The core complex subunits were downloaded from CORUM database (https://mips.helmholtz-muenchen.de/corum/#).
# 13
# 14 The BRCA (Breast invasive carcinoma) Proteomics data was downloaded from CPTAC (Clinical Proteomic Tumor Analysis Consortium) data portal (https://cptac-data-portal.georgetown.edu/cptacPublic/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 15 The COADREAD (Colorectal adenocarcinoma) Proteomics data was downloaded from CPTAC (Clinical Proteomic Tumor Analysis Consortium) data portal (https://cptac-data-portal.georgetown.edu/cptacPublic/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 16 The HNSCC (Head-and-neck Squamous Cell Carcinoma) Proteomics data was downloaded from LinkedOmics data portal (http://www.linkedomics.org/data_download/CPTAC-HNSCC/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 17 The LUAD (Lung Adenocarcinoma) Proteomics data was downloaded from LinkedOmics data portal (http://www.linkedomics.org/data_download/CPTAC-LUAD/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 18 The OV (Ovarian serous cystadenocarcinoma) Proteomics data was downloaded from CPTAC (Clinical Proteomic Tumor Analysis Consortium) data portal (https://cptac-data-portal.georgetown.edu/cptacPublic/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 19 The UCEC (Uterine Corpus Endometrial Carcinoma) Proteomics data was downloaded from LinkedOmics data portal (http://www.linkedomics.org/data_download/CPTAC-UCEC/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 20
# 21
# 22 The relationship between Kinase and the corresponding protein phosposite position was from RegPhos (http://140.138.144.141/~RegPhos/). Then, we got the 15-mer sequence window around the phosphorylated site of the peptide (up and down 7 amino acid) from the Uniprot website (http://www.uniprot.org/) as the identifier tag.
# 23 The relationship between Kinase and its targets was from PhosphositePlus (http://www.phosphosite.org/) and the phosphorylation relationships from a in-house combined signaling network.
# 24 The protein-protein interaction (PPI) network was downloaded from BIOGRID (https://thebiogrid.org/). Then, we used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 25
# 26 The ACC (Adrenocortical carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 27 The BLCA (Bladder Urothelial Carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 28 The BRCA (Breast invasive carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 29 The CESC (Cervical squamous cell carcinoma and endocervical adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 30 The CHOL (Cholangiocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# ⋮  ⋮
# 41 The LIHC (Liver hepatocellular carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 42 The LUAD (Lung adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 43 The LUSC (Lung squamous cell carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 44 The MESO (Mesothelioma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 45 The OV (Ovarian serous cystadenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 46 The PAAD (Pancreatic adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 47 The PCPG (Pheochromocytoma and Paraganglioma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 48 The PRAD (Prostate adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 49 The SARC (Sarcoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 50 The SKCM (Skin Cutaneous Melanoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 51 The STAD (Stomach adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 52 The STES (Stomach and Esophageal carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 53 The TGCT (Testicular Germ Cell Tumors) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 54 The THCA (Thyroid carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 55 The THYM (Thymoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 56 The UCEC (Uterine Corpus Endometrial Carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 57 The UCS (Uterine Carcinosarcoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 58 The UVM (Uveal Melanoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 59 The relationship between transcription factor and its targets was downloaded from MsigDB (http://software.broadinstitute.org/gsea/msigdb).
# 60 The relationship between miRNA and its targets was downloaded from MsigDB (http://software.broadinstitute.org/gsea/msigdb).
# 61 The DisgeNET disease database was downloaded from http://www.disgenet.org.
# 62 Disease terms were downloaded from ParmGKB (https://www.pharmgkb.org/). Genes associated with individual disease term were inferred using GLAD4U (http://glad4u.zhang-lab.org/index.php).
# 63
# 64 The DrugBank drug database was downloaded from https://www.drugbank.ca/.
# 65 Drug terms were downloaded from ParmGKB (https://www.pharmgkb.org/). Genes associated with individual drug term were inferred using GLAD4U (http://glad4u.zhang-lab.org/index.php).
# 66 The phenotype ontology information for human was downloaded from http://human-phenotype-ontology.github.io/.
# 67
# 68
# 69 Hallmark gene sets summarize and represent specific well-defined biological states or processes and display coherent expression. See details at http://software.broadinstitute.org/gsea/msigdb/collections.jsp#H .
# 70 Muscle Gene Sets (v3) Duddy 2017
#    idType
# 1  entrezgene
# 2  entrezgene
# 3  entrezgene
# 4  entrezgene
# 5  entrezgene
# 6  entrezgene
# 7  entrezgene
# 8  entrezgene
# 9  entrezgene
# 10 entrezgene
# 11 entrezgene
# 12 entrezgene
# 13 entrezgene
# 14 entrezgene
# 15 entrezgene
# 16 entrezgene
# 17 entrezgene
# 18 entrezgene
# 19 entrezgene
# 20 entrezgene
# 21 entrezgene
# 22 phosphositeSeq
# 23 entrezgene
# 24 entrezgene
# 25 phosphositeSeq
# 26 entrezgene
# 27 entrezgene
# 28 entrezgene
# 29 entrezgene
# 30 entrezgene
# ⋮  ⋮
# 41 entrezgene
# 42 entrezgene
# 43 entrezgene
# 44 entrezgene
# 45 entrezgene
# 46 entrezgene
# 47 entrezgene
# 48 entrezgene
# 49 entrezgene
# 50 entrezgene
# 51 entrezgene
# 52 entrezgene
# 53 entrezgene
# 54 entrezgene
# 55 entrezgene
# 56 entrezgene
# 57 entrezgene
# 58 entrezgene
# 59 entrezgene
# 60 entrezgene
# 61 entrezgene
# 62 entrezgene
# 63 entrezgene
# 64 entrezgene
# 65 entrezgene
# 66 entrezgene
# 67 entrezgene
# 68 entrezgene
# 69 entrezgene
# 70 entrezgene

# %%
# SE1Result <- WebGestaltR(
#   enrichMethod = "GSEA", organism = "hsapiens",
#   enrichDatabase = "geneontology_Biological_Process", interestGeneFile = "/content/SE1rankedgenes.rnk",
#   interestGeneType = "genesymbol", sigMethod = "top", topThr = 10, minNum = 5)

# SE2Result <- WebGestaltR(
#   enrichMethod = "GSEA", organism = "hsapiens",
#   enrichDatabase = "geneontology_Biological_Process", interestGeneFile = "/content/SE2rankedgenes.rnk",
#   interestGeneType = "genesymbol", sigMethod = "top", topThr = 10, minNum = 5)

# STICResult <- WebGestaltR(
#   enrichMethod = "GSEA", organism = "hsapiens",
#   enrichDatabase = "pathwaygeneontology_Biological_Process_KEGG", interestGeneFile = "/content/STICrankedgenes.rnk",
#   interestGeneType = "genesymbol", sigMethod = "top", topThr = 10, minNum = 5)
# Out:
# Loading the functional categories...
# Loading the ID list...
# Summarizing the uploaded ID list by GO Slim data...
# Performing the enrichment analysis...
# Streaming output truncated to the last 5000 lines.
# “score does not contain minimum number of items in set for GO:1905483
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1905485
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015871
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043248
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006563
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006564
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071258
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904298
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904300
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904301
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904303
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904316
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904317
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010157
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021997
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031642
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090069
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903690
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904344
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904346
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1990768
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033624
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072682
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2000417
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2000419
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2000420
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032227
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010335
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071471
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090271
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090360
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090361
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090362
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061181
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030047
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007185
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0060221
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0060040
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904389
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904391
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904397
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033277
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0060125
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903615
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2000471
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2000473
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904692
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061792
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1990502
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036058
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036060
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090260
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0051598
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016559
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045046
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006425
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032484
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032485
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0051036
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048227
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032707
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902231
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000730
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090735
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042148
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001927
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0051601
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006409
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0051031
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071431
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035281
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003415
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003430
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003431
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006420
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031134
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045842
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901970
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902101
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071921
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071922
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1905634
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904761
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034773
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034720
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034721
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031064
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0150066
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901726
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034633
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0
# 1 hsa04668 TNF signaling pathway
# 2 hsa05016 Huntington disease
# 3 hsa04657 IL-17 signaling pathway
# 4 hsa05143 African trypanosomiasis
# 5 hsa00450 Selenocompound metabolism
# 6 hsa05134 Legionellosis
#   link
# 1 http://www.kegg.jp/kegg-bin/show_pathway?hsa04668+3569+6364+5594+5602+23118+5743+9586+1435+7412+6376+6885+7187+3553+3627+7124+1906+1326+3726+6347+2921+3659+2919+2920+7128+3383+330
# 2 http://www.kegg.jp/kegg-bin/show_pathway?hsa05016+23186+9586+146754+196385+55567+1639+8701+27019+1767+1768+1770+56171+7052+201625+5438+6648
# 3 http://www.kegg.jp/kegg-bin/show_pathway?hsa04657+3569+6364+5594+5602+23118+5743+6885+7187+3553+3627+225689+7124+3934+6347+2354+2921+2919+2920+7128+8061
# 4 http://www.kegg.jp/kegg-bin/show_pathway?hsa05143+5578+3569+3040+7064+335+3043+7412+3553+4615+7124+3383
# 5 http://www.kegg.jp/kegg-bin/show_pathway?hsa00450+9061+4141+7296
# 6 http://www.kegg.jp/kegg-bin/show_pathway?hsa05134+3553+4615+7124+3303+718+3304+2921+2919+2920
#   enrichmentScore normalizedEnrichmentScore pValue      FDR         size
# 1 -0.6895719      -1.768816                 0.000000000 0.008308537 54
# 2 -0.7370551      -1.774845                 0.000000000 0.015639599 27
# 3 -0.6720836      -1.687553                 0.000000000 0.035189098 41
# 4 -0.7036609      -1.642001                 0.000000000 0.074532465 21
# 5 -0.7945332      -1.600060                 0.004624277 0.105730207  9
# 6 -0.6854252      -1.605479                 0.001068376 0.114755559 23
#   plotPath                               leadingEdgeNum
# 1 ./Project_1767887522_GSEA/hsa04668.png 26
# 2 ./Project_1767887522_GSEA/hsa05016.png 16
# 3 ./Project_1767887522_GSEA/hsa04657.png 20
# 4 ./Project_1767887522_GSEA/hsa05143.png 11
# 5 ./Project_1767887522_GSEA/hsa00450.png  3
# 6 ./Project_1767887522_GSEA/hsa05134.png  9
#   leadingEdgeId
# 1 3569;6364;5594;5602;23118;5743;9586;1435;7412;6376;6885;7187;3553;3627;7124;1906;1326;3726;6347;2921;3659;2919;2920;7128;3383;330
# 2 23186;9586;146754;196385;55567;1639;8701;27019;1767;1768;1770;56171;7052;201625;5438;6648
# 3 3569;6364;5594;5602;23118;5743;6885;7187;3553;3627;225689;7124;3934;6347;2354;2921;2919;2920;7128;8061
# 4 5578;3569;3040;7064;335;3043;7412;3553;4615;7124;3383
# 5 9061;4141;7296
# 6 3553;4615;7124;3303;718;3304;2921;2919;2920
#   userId
# 1 BIRC3;CCL2;CCL20;CREB5;CSF1;CX3CL1;CXCL1;CXCL10;CXCL2;CXCL3;EDN1;ICAM1;IL1B;IL6;IRF1;JUNB;MAP3K7;MAP3K8;MAPK1;MAPK10;PTGS2;TAB2;TNF;TNFAIP3;TRAF3;VCAM1
# 2 CREB5;DCTN1;DNAH10;DNAH11;DNAH12;DNAH2;DNAH3;DNAH5;DNAH6;DNAH7;DNAH9;DNAI1;POLR2I;RCOR1;SOD2;TGM2
# 3 CCL2;CCL20;CXCL1;CXCL10;CXCL2;CXCL3;FOSB;FOSL1;IL1B;IL6;LCN2;MAP3K7;MAPK1;MAPK10;MAPK15;PTGS2;TAB2;TNF;TNFAIP3;TRAF3
# 4 APOA1;HBA2;HBB;ICAM1;IL1B;IL6;MYD88;PRKCA;THOP1;TNF;VCAM1
# 5 MARS;PAPSS1;TXNRD1
# 6 C3;CXCL1;CXCL2;CXCL3;HSPA1A;HSPA1B;IL1B;MYD88;TNF
#   Celltype
# 1 Secretory Epithelial (diseased)
# 2 Secretory Epithelial (diseased)
# 3 Secretory Epithelial (diseased)
# 4 Secretory Epithelial (diseased)
# 5 Secretory Epithelial (diseased)
# 6 Secretory Epithelial (diseased)

# %%
gsea
# Out:
#    geneSet  description
# 1  hsa04668 TNF signaling pathway
# 2  hsa05016 Huntington disease
# 3  hsa04657 IL-17 signaling pathway
# 4  hsa05143 African trypanosomiasis
# 5  hsa00450 Selenocompound metabolism
# 6  hsa05134 Legionellosis
# 7  hsa04612 Antigen processing and presentation
# 8  hsa05132 Salmonella infection
# 9  hsa05323 Rheumatoid arthritis
# 10 hsa00350 Tyrosine metabolism
# 11 hsa04080 Neuroactive ligand-receptor interaction
# 12 hsa04727 GABAergic synapse
# 13 hsa04725 Cholinergic synapse
# 14 hsa04216 Ferroptosis
# 15 hsa04924 Renin secretion
# 16 hsa04550 Signaling pathways regulating pluripotency of stem cells
# 17 hsa00591 Linoleic acid metabolism
# 18 hsa04974 Protein digestion and absorption
# 19 hsa04514 Cell adhesion molecules (CAMs)
# 20 hsa04975 Fat digestion and absorption
# 21 hsa04668 TNF signaling pathway
# 22 hsa04657 IL-17 signaling pathway
# 23 hsa05323 Rheumatoid arthritis
# 24 hsa05150 Staphylococcus aureus infection
# 25 hsa05166 Human T-cell leukemia virus 1 infection
# 26 hsa05168 Herpes simplex infection
# 27 hsa04064 NF-kappa B signaling pathway
# 28 hsa05167 Kaposi sarcoma-associated herpesvirus infection
# 29 hsa05145 Toxoplasmosis
# 30 hsa05310 Asthma
# 31 hsa00980 Metabolism of xenobiotics by cytochrome P450
# 32 hsa00620 Pyruvate metabolism
# 33 hsa00010 Glycolysis / Gluconeogenesis
# 34 hsa04142 Lysosome
# 35 hsa04614 Renin-angiotensin system
# 36 hsa00061 Fatty acid biosynthesis
# 37 hsa05016 Huntington disease
# 38 hsa00330 Arginine and proline metabolism
# 39 hsa04728 Dopaminergic synapse
# 40 hsa00730 Thiamine metabolism
#    link
# 1  http://www.kegg.jp/kegg-bin/show_pathway?hsa04668+3569+6364+5594+5602+23118+5743+9586+1435+7412+6376+6885+7187+3553+3627+7124+1906+1326+3726+6347+2921+3659+2919+2920+7128+3383+330
# 2  http://www.kegg.jp/kegg-bin/show_pathway?hsa05016+23186+9586+146754+196385+55567+1639+8701+27019+1767+1768+1770+56171+7052+201625+5438+6648
# 22  0.7717292       2.0332127                0.000000000 0.0000000000 41
# 23  0.7660953       2.0169067                0.000000000 0.0000000000 42
# 24  0.7558302       1.9331989                0.000000000 0.0003392955 37
# 25  0.6435539       1.9108023                0.000000000 0.0005428727 97
# 26  0.6958348       1.8942841                0.000000000 0.0006785909 55
# 27  0.6931520       1.8916439                0.000000000 0.0011632987 50
# 28  0.6680767       1.8771176                0.001689189 0.0016964773 59
# 29  0.6791441       1.8642157                0.000000000 0.0019740826 53
# 30  0.8613627       1.8698821                0.000000000 0.0020357727 15
# 31 -0.5424736      -1.2809713                0.173033707 0.9432024051 17
# 32 -0.6603715      -1.2980953                0.179166666 0.9479995087  8
# 33 -0.5302315      -1.2286416                0.201327433 0.9566816102 16
# 34 -0.4152157      -1.2408285                0.148717948 0.9722796318 53
# 35 -0.2151482      -0.4130503                0.988235292 0.9974897903  7
# 36 -0.3750459      -0.6556805                0.835416665 0.9978907389  5
# 37 -0.6083522      -1.5779047                0.025287356 1.0000000000 27
# 38 -0.6671342      -1.4957344                0.053388090 1.0000000000 14
# 39 -0.4622287      -1.3258398                0.059808612 1.0000000000 40
# 40 -0.7740140      -1.4207610                0.071881607 1.0000000000  6
#    plotPath                               leadingEdgeNum
# 1  ./Project_1767887522_GSEA/hsa04668.png 26
# 2  ./Project_1767887522_GSEA/hsa05016.png 16
# 3  ./Project_1767887522_GSEA/hsa04657.png 20
# 4  ./Project_1767887522_GSEA/hsa05143.png 11
# 5  ./Project_1767887522_GSEA/hsa00450.png  3
# 6  ./Project_1767887522_GSEA/hsa05134.png  9
# 7  ./Project_1767887522_GSEA/hsa04612.png 11
# 8  ./Project_1767887522_GSEA/hsa05132.png 13
# 9  ./Project_1767887522_GSEA/hsa05323.png 15
# 10 ./Project_1767887522_GSEA/hsa00350.png  7
# 11 ./Project_1767887522_GSEA/hsa04080.png  4
# 12 ./Project_1767887522_GSEA/hsa04727.png 27
# 13 ./Project_1767887522_GSEA/hsa04725.png  6
# 14 ./Project_1767887522_GSEA/hsa04216.png  3
# 15 ./Project_1767887522_GSEA/hsa04924.png  5
# 16 ./Project_1767887522_GSEA/hsa04550.png  5
# 17 ./Project_1767887522_GSEA/hsa00591.png  1
# 18 ./Project_1767887522_GSEA/hsa04974.png  4
# 19 ./Project_1767887522_GSEA/hsa04514.png  3
# 20 ./Project_1767887522_GSEA/hsa04975.png  2
# 21 ./Project_1767887703_GSEA/hsa04668.png 18
# 22 ./Project_1767887703_GSEA/hsa04657.png 14
# 23 ./Project_1767887703_GSEA/hsa05323.png 18
# 24 ./Project_1767887703_GSEA/hsa05150.png 12
# 25 ./Project_1767887703_GSEA/hsa05166.png 22
# 26 ./Project_1767887703_GSEA/hsa05168.png 15
# 27 ./Project_1767887703_GSEA/hsa04064.png 14
# 28 ./Project_1767887703_GSEA/hsa05167.png 15
# 29 ./Project_1767887703_GSEA/hsa05145.png 14
# 30 ./Project_1767887703_GSEA/hsa05310.png  7
# 31 ./Project_1767887703_GSEA/hsa00980.png  5
# 23 CCL2;CSF1;CXCL1;CXCL12;HLA-DMB;HLA-DPA1;HLA-DPB1;HLA-DQB1;HLA-DRB1;HLA-DRB5;ICAM1;IL1A;IL1B;IL23A;IL6;JUN;TGFB2;TNF
# 24 C1R;C1S;C3;CFB;CFD;HLA-DMB;HLA-DPA1;HLA-DPB1;HLA-DQB1;HLA-DRB1;HLA-DRB5;ICAM1
# 25 ADCY8;ATF3;CCND1;CCND2;EGR1;EGR2;FOSL1;HLA-DMB;HLA-DPA1;HLA-DPB1;HLA-DQB1;HLA-DRB1;HLA-DRB5;ICAM1;IL1R1;IL6;JUN;MYC;NRP1;TGFB2;TNF;XBP1
# 26 C3;CCL2;HLA-DMB;HLA-DPA1;HLA-DPB1;HLA-DQB1;HLA-DRB1;HLA-DRB5;IL6;JUN;MAP3K7;NXF1;PER3;TNF;TNFSF14
# 27 BIRC3;CXCL12;CXCL2;GADD45B;ICAM1;IL1B;IL1R1;MAP3K7;PTGS2;SYK;TNF;TNFAIP3;TNFSF14;TRAF3
# 28 C3;CCND1;CDK6;CXCL1;CXCL2;CXCL3;ICAM1;IL6;JUN;MYC;PTGS2;RCAN1;SYK;TRAF3;UBB
# 29 BIRC3;HLA-DMB;HLA-DPA1;HLA-DPB1;HLA-DQB1;HLA-DRB1;HLA-DRB5;HSPA1A;HSPA1B;LAMB2;LAMB3;LDLR;MAP3K7;TNF
# 30 HLA-DMB;HLA-DPA1;HLA-DPB1;HLA-DQB1;HLA-DRB1;HLA-DRB5;TNF
# 31 ADH6;ALDH1A3;ALDH3B1;CYP1B1;GSTA1
# 32 ACACA;ACSS1;ACSS2;ME1;ME2
# 33 ACSS1;ADH6;ALDH1A3;ALDH3B1;ENO2;GALM
# 34 AP3M2;AP4M1;ARSA;ARSB;CD68;CTNS;CTSE;CTSS;DNASE2;FUCA1;GALC;GNPTAB;IGF2R;LAPTM5;MAN2B1;MCOLN1;NAGA;NPC1;SMPD1;SORT1;TCIRG1;TPP1
# 35 ACE;AGT;ANPEP;CPA3;LNPEP;PREP;THOP1
# 36 ACACA;ACSBG1;ACSL1;OXSM
# 37 DNAH10;DNAH11;DNAH12;DNAH2;DNAH3;DNAH5;DNAH6;DNAH7;DNAH9;DNAI1;PLCB4
# 38 CKB;MAOA;MAOB;P4HA1;P4HA2
# 39 GNB4;GNB5;GNG11;LRTOMT;MAOA;MAOB;MAPK10;MAPK13;PLCB4;PPP2R5B;SCN1A
# 40 AK1
#    Celltype
# 1  Secretory Epithelial (diseased)
# 2  Secretory Epithelial (diseased)
# 3  Secretory Epithelial (diseased)
# 4  Secretory Epithelial (diseased)
# 5  Secretory Epithelial (diseased)
# 6  Secretory Epithelial (diseased)
# 7  Secretory Epithelial (diseased)
# 8  Secretory Epithelial (diseased)
# 9  Secretory Epithelial (diseased)
# 10 Secretory Epithelial (diseased)
# 11 Secretory Epithelial (diseased)
# 12 Secretory Epithelial (diseased)
# 13 Secretory Epithelial (diseased)
# 14 Secretory Epithelial (diseased)
# 15 Secretory Epithelial (diseased)
# 16 Secretory Epithelial (diseased)
# 17 Secretory Epithelial (diseased)
# 18 Secretory Epithelial (diseased)
# 19 Secretory Epithelial (diseased)
# 20 Secretory Epithelial (diseased)
# 21 Secretory Epithelial (benign)
# 22 Secretory Epithelial (benign)
# 23 Secretory Epithelial (benign)
# 24 Secretory Epithelial (benign)
# 25 Secretory Epithelial (benign)
# 26 Secretory Epithelial (benign)
# 27 Secretory Epithelial (benign)
# 28 Secretory Epithelial (benign)
# 29 Secretory Epithelial (benign)
# 30 Secretory Epithelial (benign)
# 31 Secretory Epithelial (benign)
# 32 Secretory Epithelial (benign)
# 33 Secretory Epithelial (benign)
# 34 Secretory Epithelial (benign)
# 35 Secretory Epithelial (benign)
# 36 Secretory Epithelial (benign)
# 37 Secretory Epithelial (benign)
# 38 Secretory Epithelial (benign)
# 39 Secretory Epithelial (benign)
# 40 Secretory Epithelial (benign)

# %% [markdown]
# **6. Plot the dot plot**

# %%
ggplot(gsea, aes(x = Celltype, y = description)) +
  geom_point(aes(size= FDR, color = pValue)) +
  scale_color_gradient(low = "yellow", high = "blue", name = "pValue") +
  scale_size_continuous(range = c(1, 10)) +
  theme_minimal() +
  labs(
    title = "Gene set enrichment analysis of benign and diseased secretory epithelial cells",
    x = "Cell Types",
    y = "Pathway Description"
  ) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        plot.title = element_text(size = 14, face = "bold", hjust = 0.8))
        #p53 pathway
        # change to show expression, and colour is fdr
# Out:
# plot without title

# %%
gsea_filtered <- gsea[gsea$FDR < 0.05, ]

ggplot(
  gsea_filtered,
  aes(x = Celltype, y = description)
) +
  geom_point(
    aes(size = -log10(FDR), color = FDR),
    alpha = 0.8
  ) +
  scale_color_gradient(
    low = "red",
    high = "blue",
    name = "FDR"
  ) +
  scale_size_continuous(
    name = expression(-log[10]~"FDR"),
    range = c(2, 10)
  ) +
  theme_minimal() +
  labs(
    title = "Gene set enrichment analysis of\nbenign and diseased secretory epithelial cells",
    x = "Cell type",
    y = "Enriched pathway"
  ) +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 14, face = "bold", hjust = 0.5),
    legend.position = "right",
    plot.margin = margin(t = 20, r = 20, b = 10, l = 5)
  )
# Out:
# plot without title

# %% [markdown]
# ##**Linear regression**
# * We can assess correlations in gene expression between 2 genes in one or two cell types

# %% [markdown]
# **1. Subset the data to secretory epithelial-1 and secretory epithelial-2 again**

# %%
secretorymeta<- subset(metadata, metadata$Celltype %in%c('Secretory Epithelial-1','Secretory Epithelial-2'))
secretoryexp<- subset(exp_data, rownames(exp_data) %in% secretorymeta$CellID)

# %% [markdown]
# **2. Create a new column in the metadata with JUNB and IER2 expression for each cell**

# %%
secretorymeta$JUNB<-exp_data[row.names(secretoryexp),"JUNB"]
secretorymeta$IER2<-exp_data[row.names(secretoryexp),"IER2"]

# %% [markdown]
# **3. Subset the secretory metadata to contain only cells with JUNB and IER2 expression equal to or greater than 0**

# %%
filtered_meta <- secretorymeta %>%
  filter(JUNB >= 0 & IER2 >= 0)

# %% [markdown]
# **4. Run the linear regression model**

# %%
model <- lm(JUNB ~ IER2, data = filtered_meta)
summary(model)

library(dplyr)
library(broom)
model_table <- tidy(model) %>%
  mutate(
    estimate = round(estimate, 3),
    std.error = round(std.error, 3),
    statistic = round(statistic, 2),
    p.value = signif(p.value, 3)
  )

model_table

model_stats <- glance(model) %>%
  select(r.squared, adj.r.squared, nobs) %>%
  mutate(across(everything(), ~ round(.x, 3)))

model_stats

predictions <- predict(
  model,
  newdata = filtered_meta,
  interval = "confidence",  # use "prediction" for prediction interval
  level = 0.95
)
# Out:
# Call:
# lm(formula = JUNB ~ IER2, data = filtered_meta)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.16872 -0.33067 -0.01919  0.30638  1.32453
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.54746    0.02242   24.42   <2e-16 ***
# IER2         0.33560    0.02261   14.84   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4385 on 1450 degrees of freedom
# Multiple R-squared:  0.1319,	Adjusted R-squared:  0.1313
# F-statistic: 220.3 on 1 and 1450 DF,  p-value: < 2.2e-16
#   term        estimate std.error statistic p.value
# 1 (Intercept) 0.547    0.022     24.42     1.35e-110
# 2 IER2        0.336    0.023     14.84      1.70e-46
#   r.squared adj.r.squared nobs
# 1 0.132     0.131         1452
#   CellID    Patient Author  Tissue                      Disease_stage Age
# 1 sc_b1_B08 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 2 sc_b1_C15 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 3 sc_b1_C21 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 4 sc_b1_D23 33572   Hu_2020 Benign fallopian tube cells Benign        64
# 5 sc_b1_E04 34350   Hu_2020 Benign fallopian tube cells Benign        50
# 6 sc_b1_F13 33572   Hu_2020 Benign fallopian tube cells Benign        64
#   n_genes n_genes_by_counts total_counts pct_counts_in_top_50_genes
# 1 2298    2298              193108       24.94614
# 2 1793    1793              279434       19.77569
# 3 2195    2195              273332       21.42925
# 4 2548    2548              153738       21.94838
# 5 2085    2085              241450       22.78360
# 6 2601    2601              170120       18.58218
#   pct_counts_in_top_100_genes pct_counts_in_top_200_genes
# 1 32.24620                    42.47468
# 2 27.73965                    39.91712
# 3 29.14441                    39.78897
# 4 30.19293                    40.68935
# 5 30.74881                    41.84427
# 6 26.55361                    37.08030
#   pct_counts_in_top_500_genes leiden Celltype               JUNB      IER2
# 1 62.87777                    1      Secretory Epithelial-2 0.3025177 1.456976
# 2 66.52304                    1      Secretory Epithelial-2 1.1349314 1.367442
# 3 61.51530                    1      Secretory Epithelial-2 0.7718080 1.329020
# 4 60.64213                    0      Secretory Epithelial-1 1.2997562 1.379020
# 5 64.16691                    1      Secretory Epithelial-2 1.4562941 1.867987
# 6 57.66165                    0      Secretory Epithelial-1 0.6963351 1.206013
#   fit       lwr       upr
# 1 1.0364194 1.0013187 1.071520
# 2 1.0063721 0.9742111 1.038533
# 3 0.9934777 0.9625075 1.024448
# 4 1.0102575 0.9777287 1.042786
# 5 1.1743535 1.1239104 1.224797
# 6 0.9521969 0.9246737 0.979720

# %% [markdown]
# **5.Create a scatter plot of JUNB expression vs IER2 expression**

# %%
geneexpression <- ggplot(filtered_meta, aes(x = JUNB, y = IER2)) +
                geom_point() +
                geom_smooth(method = "lm", color = "red", se = TRUE) +
                theme_minimal() +
                labs(title = "JUNB Expression vs.IER2 Expression",
                x = "JUNB Expression",
                y = "IER2 Expression") +
                theme(axis.text.x = element_text(angle = 45, hjust = 1))
geneexpression
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# **6. Add the Rsquared value onto the plot**

# %%
geneexpression <- ggplot(filtered_meta, aes(x = IER2, y = JUNB)) +
  geom_point(alpha = 0.6, size = 2) +
  geom_smooth(method = "lm", color = "red", se = TRUE) +
  theme_minimal() +
  labs(
    title = "Association between IER2 and JUNB expression",
    x = "IER2 expression",
    y = "JUNB expression"
  ) +
  annotate(
    "text",
    x = Inf,
    y = Inf,
    label = paste0("R² = ", round(r_squared, 3)),
    hjust = 1.1,
    vjust = 1.5,
    size = 5
  )

# Plot coloured by Disease Stage
stagegeneexpression <- geneexpression +
  geom_point(aes(color = Disease_stage), alpha = 0.7, size = 2) +
  scale_color_brewer(palette = "Dark2") +
  labs(color = "Disease stage")

# Plot coloured by Tissue
tissuegeneexpression <- geneexpression +
  geom_point(aes(color = Tissue), alpha = 0.7, size = 2) +
  scale_color_brewer(palette = "Dark2") +
  labs(color = "Tissue")

# Display plots
geneexpression
stagegeneexpression
tissuegeneexpression
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# **7.Colour the points by disease stage or tissue type**

# %%
stagegeneexpression<- geneexpression + geom_point(aes(color=Disease_stage)) +
  scale_color_brewer(palette = "Dark2")
stagegeneexpression

tissuegeneexpression<- geneexpression + geom_point(aes(color=Tissue))+
  scale_color_brewer(palette = "Dark2")
tissuegeneexpression
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# ##**Correlate several genes against eachother using a correlation matrix**

# %% [markdown]
# **1. Remove values with a standard deviation of 0, as this will break the correlation matrix**

# %%
secretoryexp<- secretoryexp[,apply(secretoryexp,2, sd) > 0]

# %% [markdown]
# **2. Correlate genes against eachother**

# %%
cordata<-cor(secretoryexp [colnames(secretoryexp)],
             secretoryexp[colnames(secretoryexp)])

# %% [markdown]
# **3. Plot a heatmap of the correlation matrix of genes with a correlation score of >0.6**
# * Define the genes with a correlation score of >0.6
# * Subset the correlation matrix to these genes only
# * Plot as a heatmap

# %%
upper_tri <- upper.tri(cordata)
high_corr<-which(upper_tri & cordata>0.6, arr.ind=TRUE)

corrplot <- cordata[rownames(cordata) %in% rownames(high_corr),]
corrplot <- corrplot[,colnames(corrplot) %in% rownames(high_corr)]

heatmap(corrplot)
# Out:
# plot without title

# %%
# Identify upper triangle correlations
upper_tri <- upper.tri(cordata)
high_corr <- which(upper_tri & cordata > 0.6, arr.ind = TRUE)

# Get unique gene names involved in high correlations
genes_to_plot <- unique(c(rownames(cordata)[high_corr[,1]],
                          colnames(cordata)[high_corr[,2]]))

# Subset the correlation matrix
corrplot_matrix <- cordata[genes_to_plot, genes_to_plot]
par(mar = c(10, 10, 10, 2))

# Plot heatmap
heatmap(
  corrplot_matrix,
  main = "Highly Correlated Genes in Secretory Epithelial Cells",
  xlab = "Genes",
  ylab = "Genes",
  margins = c(6, 6),col = colorRampPalette(c("light yellow","pink","red"))(100),
  cex.main = 0.2,
)
# Out:
# Plot with title “Highly Correlated Genes in Secretory Epithelial Cells”
